# %%
###LIBRARIES
# %matplotlib notebook
# %config InlineBackend.figure_format = 'retina'
import cv2
import numpy as np
from matplotlib import pyplot as plt
import shutil
from pathlib2 import Path
import pandas as pd
import sys
from enum import Enum
import os
import time

# %% [markdown]
# ## Global variables -- Path to database files

# %%
#GLOBAL VARIABLES
#PAth to folder with database
str_db_dir = '../../../data/CADDY_gestures_complete_v2_release/'
str_csvDatabase = 'CADDY_gestures_all_true_positives_release_v2.csv'
extract_ROI = False
str_ROI_dir = 'hands-ROIs/'
shutil_ignore_patterns = ('*.jpg','*~','*.csv*')

# %% [markdown]
# ### Create directory tree for hand ROIs

# %% [markdown]
# #### Do this only once

# %%
#SNIPPETS
#copy a directory tree with or without files
def copytree(src, dst, symlinks=False, ignore=None, only_dirs=True):
    for item in os.listdir(src):
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        if os.path.isdir(s) and item != str_ROI_dir[:-1]:
            shutil.copytree(s, d, symlinks, ignore)
        elif not only_dirs:
            shutil.copy2(s, d)

#go through each scenario and create the directory tree for the haar cascade database
#following the same dir tree layout as in the database (folders of synthetic and non-synthetic images)
if os.path.isdir(str_db_dir+str_ROI_dir) is False:
    os.mkdir(str_db_dir+str_ROI_dir)
dst = os.path.join(str_db_dir,str_ROI_dir)
copytree(str_db_dir, dst, False, ignore=shutil.ignore_patterns(*shutil_ignore_patterns),only_dirs=True)

# %% [markdown]
# ### Read database -- only raw data

# %%
#Read original file with non-altered stereo images
tmp_df = pd.read_csv(str_db_dir+str_csvDatabase)
database_source_df = tmp_df.loc[tmp_df['synthetic'] == 0]
database_source_df.head(10)
# Out:
#     index   scenario                                        stereo left  \
# 0       0  biograd-A  /biograd-A/true_positives/raw/biograd-A_00000_...
# 10     10  biograd-A  /biograd-A/true_positives/raw/biograd-A_00001_...
# 20     20  biograd-A  /biograd-A/true_positives/raw/biograd-A_00002_...
# 30     30  biograd-A  /biograd-A/true_positives/raw/biograd-A_00003_...
# 40     40  biograd-A  /biograd-A/true_positives/raw/biograd-A_00004_...
# 50     50  biograd-A  /biograd-A/true_positives/raw/biograd-A_00005_...
# 60     60  biograd-A  /biograd-A/true_positives/raw/biograd-A_00006_...
# 70     70  biograd-A  /biograd-A/true_positives/raw/biograd-A_00007_...
# 80     80  biograd-A  /biograd-A/true_positives/raw/biograd-A_00008_...
# 90     90  biograd-A  /biograd-A/true_positives/raw/biograd-A_00009_...
#
#                                          stereo right     label name  \
# 0   /biograd-A/true_positives/raw/biograd-A_00000_...  num_delimiter
# 10  /biograd-A/true_positives/raw/biograd-A_00001_...  num_delimiter
# 20  /biograd-A/true_positives/raw/biograd-A_00002_...  num_delimiter
# 30  /biograd-A/true_positives/raw/biograd-A_00003_...  num_delimiter
# 40  /biograd-A/true_positives/raw/biograd-A_00004_...  num_delimiter
# 50  /biograd-A/true_positives/raw/biograd-A_00005_...  num_delimiter
# 60  /biograd-A/true_positives/raw/biograd-A_00006_...           five
# 70  /biograd-A/true_positives/raw/biograd-A_00007_...           five
# 80  /biograd-A/true_positives/raw/biograd-A_00008_...           five
# 90  /biograd-A/true_positives/raw/biograd-A_00009_...           five
#
#     label id           roi left          roi right  synthetic  \
# 0         10    [237,236,54,65]    [155,236,54,65]          0
# 10        10    [230,230,61,79]    [147,230,61,79]          0
# 20        10    [222,230,72,75]    [139,230,72,75]          0
# 30        10    [231,231,62,83]    [148,231,62,83]          0
# 40        10    [222,219,70,76]    [138,219,70,76]          0
# 50        10    [223,220,68,81]    [139,220,68,81]          0
# 60        15    [220,209,86,90]    [136,209,86,90]          0
# 70        15  [210,200,110,118]  [127,200,110,118]          0
# 80        15   [229,205,98,101]   [145,205,98,101]          0
# 90        15   [233,199,98,115]   [150,199,98,115]          0
#
#     iqa_mdm_entropy  iqa_mdm_d  iqa_mdm_dcomp distortion param 1  param 2
# 0          6.971026   0.957653       0.902000        NaN     NaN      NaN
# 10         6.977803   0.958442       0.885512        NaN     NaN      NaN
# 20         6.930135   0.958565       0.885733        NaN     NaN      NaN
# 30         6.948746   0.958243       0.885593        NaN     NaN      NaN
# 40         7.175039   0.955913       0.875217        NaN     NaN      NaN
# 50         7.164511   0.956243       0.894149        NaN     NaN      NaN
# 60         7.118584   0.957484       0.917649        NaN     NaN      NaN
# 70         7.057821   0.957349       0.895427        NaN     NaN      NaN
# 80         6.981269   0.957604       0.893355        NaN     NaN      NaN
# 90         6.957809   0.958578       0.900619        NaN     NaN      NaN

# %%
#Iterate through database
file_cc = 0
stereo_view = ['left', 'right']
for index, row in database_source_df.iterrows():
    if file_cc > -1: #hackable condition helpful if few loops want to be tested
        for view in stereo_view:
            #select left or right stereo pair        
            str_selected_img = str_db_dir + row['stereo '+view][1::]
            #str_selected_img = str_db_dir + '/biograd-C/true_positives/raw/biograd-C_00080_right.jpg'
            #read image
            img = cv2.imread(str_selected_img,cv2.IMREAD_COLOR)
        
            #extract roi info from csv file
            if row['roi '+view]:
                try: #avoid empty cells
                    str_roi_params = row['roi '+view][1:-1] #get rid of the brackets
                    str_roi_params = str_roi_params.replace(";",",") #in case of more than one ROI
                    roi_params = str_roi_params.split(",")
                    no_rois = int(len(roi_params) / 4) #check number of ROIs
                    #print(roi_params)

                    #crop each ROI in the image
                    for i in range(0,no_rois):
                        #get params of the ROI
                        topx = int(roi_params[4*i])
                        topy = int(roi_params[(4*i)+1])
                        width = int(roi_params[(4*i)+2])
                        height = int(roi_params[(4*i)+3])
                        #extract ROI
                        #print(topx, topy, width, height)
                        patch_image = img[topy:(topy+height-1), topx:(topx+width-1)]
                        #set file path to save the ROI
                        str_patch_path = (str_db_dir + str_ROI_dir + row['stereo '+view][1::])
                        #print(str_patch_path)
                        cv2.imwrite(str_patch_path,patch_image)
                except:
                    print(str_selected_img)
        
            #See progress
            time.sleep(.1)
            file_cc+=1
            sys.stdout.write("\rProgress: " + str(file_cc) + " images ...")
# Out:
# Progress: 5565 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_00079_right.jpg
# Progress: 5593 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_00093_right.jpg
# Progress: 5597 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_00095_right.jpg
# Progress: 5727 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_00160_right.jpg
# Progress: 5826 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_00210_left.jpg
# Progress: 5828 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_00211_left.jpg
# Progress: 5830 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_00212_left.jpg
# Progress: 5907 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_00250_right.jpg
# Progress: 5963 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_00278_right.jpg
# Progress: 5965 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_00279_right.jpg
# Progress: 5967 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_00280_right.jpg
# Progress: 6007 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_00300_right.jpg
# Progress: 6201 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_00397_right.jpg
# Progress: 7813 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01203_right.jpg
# Progress: 7815 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01204_right.jpg
# Progress: 7833 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01213_right.jpg
# Progress: 7841 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01217_right.jpg
# Progress: 7843 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01218_right.jpg
# Progress: 7845 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01219_right.jpg
# Progress: 7847 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01220_right.jpg
# Progress: 7871 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01232_right.jpg
# Progress: 7873 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01233_right.jpg
# Progress: 7875 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01234_right.jpg
# Progress: 7877 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01235_right.jpg
# Progress: 7961 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01277_right.jpg
# Progress: 7963 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01278_right.jpg
# Progress: 7965 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01279_right.jpg
# Progress: 7981 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01287_right.jpg
# Progress: 8009 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01301_right.jpg
# Progress: 8049 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01321_right.jpg
# Progress: 8055 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01324_right.jpg
# Progress: 8057 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01325_right.jpg
# Progress: 8098 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01346_left.jpg
# Progress: 8135 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01364_right.jpg
# Progress: 8137 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01365_right.jpg
# Progress: 8139 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01366_right.jpg
# Progress: 8141 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01367_right.jpg
# Progress: 8253 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01423_right.jpg
# Progress: 8255 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01424_right.jpg
# Progress: 8257 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01425_right.jpg
# Progress: 8912 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01753_left.jpg
# Progress: 8914 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01754_left.jpg
# Progress: 8918 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01756_left.jpg
# Progress: 8920 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01757_left.jpg
# Progress: 8922 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01758_left.jpg
# Progress: 8924 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01759_left.jpg
# Progress: 8926 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01760_left.jpg
# Progress: 8928 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01761_left.jpg
# Progress: 8932 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01763_left.jpg
# Progress: 8936 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01765_left.jpg
# Progress: 8938 images ...../../../data/CADDY_gestures_complete_v2_release/biograd-C/true_positives/raw/biograd-C_01766_left.jpg
# Progress: 11869 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00015_right.jpg
# Progress: 11870 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00016_left.jpg
# Progress: 11873 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00017_right.jpg
# Progress: 11878 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00020_left.jpg
# Progress: 11889 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00025_right.jpg
# Progress: 12046 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00104_left.jpg
# Progress: 12048 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00105_left.jpg
# Progress: 12055 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00108_right.jpg
# Progress: 12057 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00109_right.jpg
# Progress: 12063 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00112_right.jpg
# Progress: 12065 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00113_right.jpg
# Progress: 12146 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00154_left.jpg
# Progress: 12150 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00156_left.jpg
# Progress: 12347 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00254_right.jpg
# Progress: 12385 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00273_right.jpg
# Progress: 12387 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00274_right.jpg
# Progress: 12388 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00275_left.jpg
# Progress: 12471 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00316_right.jpg
# Progress: 12473 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00317_right.jpg
# Progress: 12475 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00318_right.jpg
# Progress: 12477 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00319_right.jpg
# Progress: 12485 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00323_right.jpg
# Progress: 12487 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00324_right.jpg
# Progress: 12536 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00349_left.jpg
# Progress: 12786 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00474_left.jpg
# Progress: 12851 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00506_right.jpg
# Progress: 12993 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00577_right.jpg
# Progress: 13161 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00661_right.jpg
# Progress: 13168 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00665_left.jpg
# Progress: 13190 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00676_left.jpg
# Progress: 13224 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00693_left.jpg
# Progress: 13226 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00694_left.jpg
# Progress: 13230 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00696_left.jpg
# Progress: 13242 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00702_left.jpg
# Progress: 13245 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00703_right.jpg
# Progress: 13246 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00704_left.jpg
# Progress: 13294 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00728_left.jpg
# Progress: 13297 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00729_right.jpg
# Progress: 13393 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00777_right.jpg
# Progress: 13398 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00780_left.jpg
# Progress: 13408 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00785_left.jpg
# Progress: 13414 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00788_left.jpg
# Progress: 13424 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00793_left.jpg
# Progress: 13444 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00803_left.jpg
# Progress: 13450 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00806_left.jpg
# Progress: 13541 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00851_right.jpg
# Progress: 13542 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00852_left.jpg
# Progress: 13545 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00853_right.jpg
# Progress: 13547 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00854_right.jpg
# Progress: 13549 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00855_right.jpg
# Progress: 13551 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_00856_right.jpg
# Progress: 13862 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01012_left.jpg
# Progress: 13906 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01034_left.jpg
# Progress: 13912 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01037_left.jpg
# Progress: 13922 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01042_left.jpg
# Progress: 13925 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01043_right.jpg
# Progress: 13962 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01062_left.jpg
# Progress: 13964 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01063_left.jpg
# Progress: 13966 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01064_left.jpg
# Progress: 13968 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01065_left.jpg
# Progress: 13980 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01071_left.jpg
# Progress: 14054 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01108_left.jpg
# Progress: 14661 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01411_right.jpg
# Progress: 14726 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01444_left.jpg
# Progress: 14816 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01489_left.jpg
# Progress: 14867 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01514_right.jpg
# Progress: 14873 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01517_right.jpg
# Progress: 14875 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01518_right.jpg
# Progress: 15019 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01590_right.jpg
# Progress: 15020 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01591_left.jpg
# Progress: 15041 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01601_right.jpg
# Progress: 15043 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01602_right.jpg
# Progress: 15245 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01703_right.jpg
# Progress: 15253 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01707_right.jpg
# Progress: 15291 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01726_right.jpg
# Progress: 15302 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01732_left.jpg
# Progress: 15308 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01735_left.jpg
# Progress: 15312 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_01737_left.jpg
# Progress: 16045 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_02103_right.jpg
# Progress: 16049 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_02105_right.jpg
# Progress: 16475 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_02318_right.jpg
# Progress: 16477 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_02319_right.jpg
# Progress: 16479 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_02320_right.jpg
# Progress: 16546 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_02354_left.jpg
# Progress: 16574 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_02368_left.jpg
# Progress: 16576 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_02369_left.jpg
# Progress: 17139 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_02650_right.jpg
# Progress: 17439 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_02800_right.jpg
# Progress: 17791 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_02976_right.jpg
# Progress: 17847 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_03004_right.jpg
# Progress: 17919 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_03040_right.jpg
# Progress: 17921 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_03041_right.jpg
# Progress: 17933 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_03047_right.jpg
# Progress: 18111 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_03136_right.jpg
# Progress: 18115 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_03138_right.jpg
# Progress: 18119 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_03140_right.jpg
# Progress: 18127 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_03144_right.jpg
# Progress: 18131 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_03146_right.jpg
# Progress: 18135 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_03148_right.jpg
# Progress: 18139 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_03150_right.jpg
# Progress: 18195 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_03178_right.jpg
# Progress: 18378 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_03270_left.jpg
# Progress: 18386 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_03274_left.jpg
# Progress: 18389 images ...../../../data/CADDY_gestures_complete_v2_release/genova-A/true_positives/raw/genova-A_03275_right.jpg
# Progress: 18478 images ...
